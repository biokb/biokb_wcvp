# %% [markdown]
# # RDF turtle creation

# %%
from sqlalchemy import create_engine
from biokb_wcvp.rdf.turtle import TurtleCreator

# %%
engine = create_engine("mysql+pymysql://biokb_user:biokb_passwd@localhost:3306/biokb")

# %%
tc = TurtleCreator(engine)
tc.create_all_ttls()
# Out:
# ...
# Creating plant-location links: 100%|██████████| 437353/437353 [04:09<00:00, 1753.32it/s]
# '/home/ceb/.biokb/wcvp/data/ttls.zip'

# %%
from eralchemy import render_er
from biokb_wcvp.db.models import Base
import os

# %% [markdown]
# # Create entity-relationship diagram

# %% [markdown]
# This notebook is used to generate an entity-relationship diagram from the SQLAlchemy models defined in the `biokb_wcvp` package.
#
# To do this we have to clone the repository and install the required dependencies.

# %%
render_er(Base, os.path.join("..", "docs", "imgs", "erd_from_sqlalchemy.png"))

# %% [markdown]
# # Import RDF turtle in Neo4j database

# %%
from biokb_wcvp.rdf.neo4j_importer import Neo4jImporter

# %%
ni = Neo4jImporter(
    neo4j_user="neo4j",
    neo4j_pwd="neo4j_password",
    neo4j_uri="bolt://localhost:7687",
)

# %%
ni.import_ttls()
# Out:
# Uniqueness constraint on :Resource(uri) found.
#
#
# The store is now: Open
# Processing tdwg_locations.ttl: 100%|██████████| 3/3 [03:31<00:00, 70.43s/it]
# The store is now: Closed
# IMPORTED 4758928 TRIPLES
# True

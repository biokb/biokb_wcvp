# %%
from biokb_wcvp import DbManager, TurtleCreator, Neo4jImporter
import os
from dotenv import load_dotenv

# %%
load_dotenv(os.path.join("..", ".env_template"), override=True)
# Out:
# True

# %% [markdown]
# # Test the workflow with default settings
#
# Before starting the import data into MySQL and Neo4j start compose with with:
# ```bash
# podman-compose -f docker-compose.db_neo.yml up -d
# ```

# %%
DbManager().import_data(keep_files=True)
TurtleCreator().create_ttls()

# %%
Neo4jImporter().import_ttls()
# Out:
# INFO:biokb_wcvp.rdf.neo4j_importer:Start importing all turtle file in Neo4J.
# INFO:biokb_wcvp.rdf.neo4j_importer:Delete an existing graph in Neo4J with node label DbWCVP.
# Uniqueness constraint on :Resource(uri) found.
#
#
# The store is now: Open
# Processing tdwg_locations.ttl: 100%|██████████| 3/3 [03:46<00:00, 75.51s/it]
# The store is now: Closed
# IMPORTED 4774937 TRIPLES
# True

# %% [markdown]
# Open Neo4j [browser](http://localhost:7474), login with neo4j/neo4j_password

# %% [markdown]
# To shutdown the compose setup run:
# ```bash
# podman-compose -f docker-compose.db_neo.yml down
# ```
#
# Data will be not lost as it is stored in a volumes.

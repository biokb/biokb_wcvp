# %%
! uv pip install python-dotenv
# Out:
# Using Python 3.13.2 environment at: /home/ceb/workspace/github/biokb/biokb_wcvp/.venv
# Audited 1 package in 8ms

# %%
from biokb_wcvp.db.manager import DbManager
from biokb_wcvp.rdf.turtle import TurtleCreator
from biokb_wcvp.rdf.neo4j_importer import Neo4jImporter
from dotenv import load_dotenv
import os.path

# %% [markdown]
# # Test the workflow with podman-compose

# %% [markdown]
# In production you should copy `.env_template` to `.env` and change passwords! For testing we are using `.env_template`.
#
# ```bash
# podman-compose -f docker-compose.db_neo.yml --env-file .env_template up -d
# ```
#
# **Tipp:** Before running the following command, please close all other applications that might use significant system resources, as running containers can be resource-intensive.

# %%
load_dotenv(os.path.join("..", ".env"))

DbManager().import_data()
TurtleCreator().create_ttls()
# Out:
# INFO:biokb_wcvp.db.manager:Using database connection: mysql+pymysql://biokb_user:***@localhost:3306/biokb
# INFO:biokb_wcvp.db.manager:Recreating database
# INFO:biokb_wcvp.tools:/home/ceb/.biokb/wcvp/data/wcvp.zip already exists. Skipping download.
# INFO:biokb_wcvp.db.manager:Reading names file into DataFrame
# INFO:biokb_wcvp.db.manager:Importing unique values in table: wcvp_taxon_rank
# INFO:biokb_wcvp.db.manager:Importing unique values in table: wcvp_taxon_status
# INFO:biokb_wcvp.db.manager:Importing unique values in table: wcvp_family
# INFO:biokb_wcvp.db.manager:Importing unique values in table: wcvp_genus
# INFO:biokb_wcvp.db.manager:Importing unique values in table: wcvp_infraspecific_rank
# INFO:biokb_wcvp.db.manager:Importing unique values in table: wcvp_lifeform_description
# INFO:biokb_wcvp.db.manager:Importing unique values in table: wcvp_climate_description
# INFO:biokb_wcvp.db.manager:Inserting plant names
# INFO:biokb_wcvp.db.tree:Building tree structure
# INFO:biokb_wcvp.db.manager:Plants imported successfully.
# INFO:biokb_wcvp.db.manager:Importing locations
# INFO:biokb_wcvp.db.manager:Inserting continents
# INFO:biokb_wcvp.db.manager:Inserting regions
# INFO:biokb_wcvp.db.manager:Inserting areas
# INFO:biokb_wcvp.db.manager:Locations imported successfully.
# INFO:biokb_wcvp.db.manager:Update tax_ids in organism table (up to 5min)
# INFO:biokb_wcvp.db.manager:import taxonomy names (up to 5min)
# INFO:biokb_wcvp.db.manager:Update tax_ids by scientific names
# INFO:biokb_wcvp.db.manager:Inherit tax_ids from accepted names
# /home/ceb/workspace/github/biokb/biokb_wcvp/src/biokb_wcvp/db/manager.py:347: SAWarning: SELECT statement has a cartesian product between FROM element(s) "wcvp_plant" and FROM element "p1".  Apply join condition(s) between each element to resolve.
#   session.execute(stmt)

# %% [markdown]
# Open Neo4j [browser](http://localhost:7474), login with neo4j/neo4j_password

# %%
Neo4jImporter().import_ttls()
